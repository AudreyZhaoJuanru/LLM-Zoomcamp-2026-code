# %%
from sqlitesearch import TextSearchIndex

sqlite_index = TextSearchIndex(
    text_fields=["question", "section", "answer"],
    keyword_fields=["course"],
    db_path="faq.db"
)

# %%
sqlite_index.count()
# Out:
# 84

# %%
results = sqlite_index.search("Can I still join the course after it started?", num_results=5)
[doc["question"] for doc in results]
# Out:
# ['I just discovered the course. Can I still join?',
#  'I missed the first homework - can I still get a certificate?',
#  'How do I start using Google Gemini models in the Module 1 notebook through the OpenAI-compatible endpoint?',
#  'Homework: Why does the content keep changing?',
#  'What happens to code saved in Codespaces if I do not commit it?']

# %%
from dotenv import load_dotenv

load_dotenv()

from rag_helper import RAGBase
from openai import OpenAI

openai_client = OpenAI()

assistant = RAGBase(
    index=sqlite_index,
    llm_client=openai_client,
)

# %%
answer = assistant.rag("Can I still join the course after it started?")
print(answer)
# Out:
# Yes, you can still join after it started. If you want to receive a certificate, make sure to submit your project while submissions are still being accepted.

# %%
answer = assistant.rag("How do I run Ollama locally?")
print(answer)
# Out:
# To run Ollama locally:
#
# 1. Install Ollama from https://ollama.com/download
#    - macOS: install the `.pkg`
#    - Windows: install the `.msi`
#    - Linux:
#      ```bash
#      curl -fsSL https://ollama.com/install.sh | sh
#      ```
#
# 2. Start a model in your terminal:
#    ```bash
#    ollama run llama3
#    ```
#    This downloads the model and opens a chat-like local interface.
#
# 3. Test that the local server is running:
#    ```bash
#    curl http://localhost:11434
#    ```
#
# 4. If you want to use it from Python:
#    ```bash
#    pip install ollama
#    ```
#
#    Example:
#    ```python
#    import ollama
#
#    response = ollama.chat(
#        model='llama3',
#        messages=[{"role": "user", "content": your_prompt}]
#    )
#
#    print(response['message']['content'])
#    ```
#
# If you hit a connection refused error, restart the server with:
#
# ```bash
# !nohup ollama serve > nohup.out 2>&1 &
# ```

# %%
answer = assistant.rag("How do I run Olama locally?")
print(answer)
# Out:
# Install Ollama from https://ollama.com/download, then run:
#
# ```bash
# ollama run llama3
# ```
#
# This downloads and starts the model locally.
#
# To check that the local server is running, use:
#
# ```bash
# curl http://localhost:11434
# ```
#
# If you want to use it from Python, install the client:
#
# ```bash
# pip install ollama
# ```
#
# Then call it like this:
#
# ```python
# import ollama
#
# response = ollama.chat(
#     model='llama3',
#     messages=[{"role": "user", "content": your_prompt}]
# )
#
# print(response['message']['content'])
# ```
